# %% [markdown]
# # Temp notes and ideas
#
# * could use sentence-transformers to get sentence embeddings and then use clustering to find the most similar sentences
# * txtai is a python library that can be used to find similar sentences
# * LlamaIndex
# * langchain
# * embedchain
# * haystack with pre trained nlp model, can use as pipeline, in memory db or elasticsearch or faiss
# * will need to use a transformer model to get embeddings, and index them in a db
# * can use a transformer model to get embeddings and then use faiss to find similar embeddings
# * can use a transformer model to get embeddings and then use clustering to find similar embeddings
#
# Pipeline ideas:
# * Hash of html sites to see if changes have been made, then repull html and update embedding for that site

# %% [markdown]
# # Semantic Search Pipeline
#
# Ryan Hull, Albert Oh, Tim Hillman, Adam Lowder
#
# This notebook demonstrates how to build a semantic search pipeline using the ___ library. The pipeline consists of the following steps:

# %%
# Imports
import re
import requests
from bs4 import BeautifulSoup
import csv
from urllib.parse import urljoin
from urllib.parse import urlparse
import os
import sys
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
from IPython.display import clear_output, display

# %%
FILENAME = './data/endpoints-v4.csv'
DOMAIN = 'https://charlotte.edu'
PREPROCESSED_FILENAME = './data/preprocessed-endpoints.csv'

# Read the data from the CSV file
import csv
csv.field_size_limit(2**31 - 1)
# Out:
# 131072

# %% [markdown]
# ## Web crawl/scrape

# %%
EXCLUDE = [
    'news-articles',
    'news-events',
    'news-media',
    'linkedin',
    'facebook',
    'twitter',
    'instagram',
    'youtube',
    'flickr',
    'pinterest',
    '.com',
    '.org',
    '.net',
    '.gov',
    '.pdf',
    '.doc',
    'php',
    'mailto:',
    '@',
    'tel:',
    'javascript:',
    'tel:',
    'sms:',
    'mailto:',
    'angular',
    'react',
    '.js',
    'event',
    'corporate',
    '#',
    'image',
    'gallery',
    'taskstream-student-handbook',
]

current_display = display('Starting...', display_id=True)
progress_display = display('Starting...', display_id=True)
success_count = 0
failure_count = 0

def print_status(url, status):
    global success_count
    global failure_count
    global current_display
    global progress_display
    
    if status == 'Success':
        success_count += 1
    else:
        failure_count += 1
    # Print the most recent URL and status, and the total counts    
    current_display.update(f'Most recent URL: {url} \nStatus: {status}')
    progress_display.update(f'Successes: {success_count}, Failures: {failure_count}')
    

def remove_url_prefix(url):
    url = url.replace('http://', '').replace('https://', '').replace('www.', '')
    return url.lower()

def is_valid_url(url):
    if any(ex in url for ex in EXCLUDE) or len(url) < 8 or len(url) > 100:
        return False
    try:
        split_url = re.split('https?://', url)
        return 'mailto:' not in url and '@' not in url and 'charlotte.edu' in split_url[0] or len(split_url) > 1 and 'charlotte.edu' in split_url[1]
    except Exception as e:
        print(f'Exception: {e}')
        return False
    
def write_to_csv(valid_endpoints, failed_endpoints):
    # Export the endpoints to a CSV file
    try:
        with open(FILENAME, 'w', newline='', encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(['URL', 'Status', 'Text'])  # Write the column labels
            for endpoint in valid_endpoints:  # Write the valid endpoints
                writer.writerow(endpoint)
            for endpoint in failed_endpoints:  # Write the failed endpoints
                writer.writerow(endpoint)
            file.flush()
            os.fsync(file.fileno())
    except Exception as e:
        print(f'Exception during file write: {e}')

def fetch_url(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            return ('Success', response.content)
        else:
            return ('Failed', None)
    except (requests.exceptions.RequestException, requests.exceptions.Timeout, ValueError):
        print(f'An error occurred while fetching {url}')
        return ('Failed', None)

def crawl_domain(domain):
    visited = set()
    to_visit = [domain.rstrip('/')]
    valid_endpoints = []
    failed_endpoints = []

    with ThreadPoolExecutor(max_workers=50) as executor:
        futures = {executor.submit(fetch_url, url): url for url in to_visit if is_valid_url(url) and url not in visited}
        visited.update(url for url in to_visit if is_valid_url(url))

        while futures:
            done, _ = concurrent.futures.wait(futures, return_when=concurrent.futures.FIRST_COMPLETED)

            for future in done:
                url = futures.pop(future)

                try:
                    data = future.result()
                except Exception as e:
                    print(f'Exception in crawl loop {url}: {e}')
                    continue
                
                status, content = data
                
                try:
                    if status == 'Success':
                        soup = BeautifulSoup(content, 'html.parser')

                        # Remove JavaScript and CSS blocks, and common sections like headers, footers, etc.
                        for script in soup(["script", "style"]):  # Remove JavaScript and CSS blocks
                            script.decompose()
                        # Remove header, footer, nav, and aside
                        for tag in soup(["header", "footer", "nav", "aside"]):
                            tag.decompose() 
                        # Remove divs with class "sidebar" or "ad"
                        for div in soup.find_all("div", class_=["sidebar", "ad"]):
                            div.decompose()
                            
                        text = soup.get_text()  # Extract text from the HTML content
                        text = ' '.join(text.split())
                        valid_endpoints.append([url, status, str(text)])  # Save the text along with the URL and status
                        print_status(url, status)
                        links = soup.find_all('a')
                        for link in links:
                            href = link.get('href')
                            if href is not None:
                                full_url = urljoin(domain, href).rstrip('/')
                                clean_url = remove_url_prefix(full_url)
                                slash_count = urlparse(clean_url).path.count('/')
                                if is_valid_url(clean_url) and slash_count <= 2 and clean_url not in visited:
                                    futures[executor.submit(fetch_url, full_url)] = full_url
                                    visited.add(clean_url)
                    else:
                        failed_endpoints.append([url, status, ''])
                        visited.add(url)
                except Exception as e:
                    print_status(url, 'Failed')
                    visited.add(url)
                    continue
        write_to_csv(valid_endpoints, failed_endpoints)
# Clear the csv file
open(FILENAME, 'w').close()

# Crawl the domain
crawl_domain(DOMAIN)
# Out:
# 'Most recent URL: https://sites.charlotte.edu/harwood/?sfid=9267&sf_paged=24 \nStatus: Success'
# 'Successes: 4785, Failures: 0'
# An error occurred while fetching http://www.opticscenter.charlotte.edu
# An error occurred while fetching https://ideas.charlotte.edu
# An error occurred while fetching https://pages.charlotte.edu/employeeownership
# An error occurred while fetching https://ofe.charlotte.edu
# An error occurred while fetching https://pages.charlotte.edu/connections
# An error occurred while fetching https://mrc.charlotte.edu
# An error occurred while fetching https://inside-chess.charlotte.edu
# An error occurred while fetching https://offcampushousing.charlotte.edu
# An error occurred while fetching https://pages.charlotte.edu/heather-smith
# An error occurred while fetching https://pages.charlotte.edu/pinku-mukherjee
# An error occurred while fetching https://pages.charlotte.edu/juan-meneses
# An error occurred while fetching https://registrar.charlotte.edu/webform/student-consent-access-education-records
# An error occurred while fetching https://webforms.charlotte.edu/emergencyunccedu/families-nineralerts-update-form
# An error occurred while fetching https://pages.charlotte.edu/camilleendacott
# An error occurred while fetching https://mygradschool.charlotte.edu/default.asp
# An error occurred while fetching https://archibus.charlotte.edu/archibus/login.axvw
# An error occurred while fetching http://plannedgiving.charlotte.edu
# An error occurred while fetching https://pages.charlotte.edu/terryshirley
# An error occurred while fetching https://clas-pages.charlotte.edu/oat/?s=video+editing&op.x=0&op.y=0
# An error occurred while fetching https://pages.charlotte.edu/jeffrey-leak
# An error occurred while fetching https://clas-math.charlotte.edu/math-placement
# An error occurred while fetching https://charlotte.edu/directory/joohyun-kim
# An error occurred while fetching https://fm311.charlotte.edu
# An error occurred while fetching https://vialab.charlotte.edu
# An error occurred while fetching https://coop.charlotte.edu/emergency-plan
# An error occurred while fetching https://advising.charlotte.edu/programs
# An error occurred while fetching http://clas-pages.charlotte.edu/joanne-maguire-robinson
# An error occurred while fetching http://clas-pages.charlotte.edu/julia-marie-robinson
# An error occurred while fetching http://clas-pages.charlotte.edu/fotini-katsanos
# An error occurred while fetching http://clas-pages.charlotte.edu/kent-brintnall
# An error occurred while fetching http://clas-pages.charlotte.edu/sean-mccloud
# An error occurred while fetching http://clas-pages.charlotte.edu/eric-hoenes
# An error occurred while fetching https://pages.charlotte.edu/dclause2
# An error occurred while fetching https://pages.charlotte.edu/dan-dupre
# An error occurred while fetching https://pages.charlotte.edu/efratant
# An error occurred while fetching https://pages.charlotte.edu/ddu2
# An error occurred while fetching https://pages.charlotte.edu/karen-cox
# An error occurred while fetching https://pages.charlotte.edu/pferdina
# An error occurred while fetching http://clas-pages.charlotte.edu/celia-sinclairAn error occurred while fetching http://clas-pages.charlotte.edu/john-reeves
#
# An error occurred while fetching https://pages.charlotte.edu/jurgen-buchenau
# An error occurred while fetching https://pages.charlotte.edu/christopher-cameron
# An error occurred while fetching https://pages.charlotte.edu/david-goldfield
# An error occurred while fetching https://pages.charlotte.edu/benny-andres
# An error occurred while fetching https://pages.charlotte.edu/karen-flint
# An error occurred while fetching https://clas-chemistry.charlotte.edu/nanosure
# An error occurred while fetching https://pages.charlotte.edu/lyn-exum
# An error occurred while fetching https://pages.charlotte.edu/tonya-wertz-orbaugh
# An error occurred while fetching http://pages.charlotte.edu/mathlearningcenter
# An error occurred while fetching https://pages.charlotte.edu/dbeete
# An error occurred while fetching https://ninerscholars.charlotte.edu/scholarshipsearch/scholarship.asp?id=1961
# An error occurred while fetching https://ninerscholars.charlotte.edu/scholarshipsearch/scholarship.asp?id=2061
# An error occurred while fetching https://socialwork.charlotte.edu/people/3075-2
# An error occurred while fetching https://ninerscholars.charlotte.edu/scholarshipsearch/scholarship.asp?id=1857
# An error occurred while fetching https://charlotte.edu/navigating-oppression
# An error occurred while fetching https://socialwork.charlotte.edu/directory/dante-d-bryant-phd
# An error occurred while fetching https://socialwork.charlotte.edu/directory/yuqi-guo-phd
# An error occurred while fetching https://socialwork.charlotte.edu/directory/tianca-crocker-phd
# An error occurred while fetching https://socialwork.charlotte.edu/directory/frances-ferrante-fusilli
# An error occurred while fetching https://socialwork.charlotte.edu/directory/jacquelyn-garcia
# An error occurred while fetching http://clas-pages.charlotte.edu/barbara-thiede
# An error occurred while fetching https://socialwork.charlotte.edu/directory/james-r-dudley-phd
# An error occurred while fetching https://socialwork.charlotte.edu/directory/kevin-edwards-knight
# An error occurred while fetching https://socialwork.charlotte.edu/people/vicky-harrisAn error occurred while fetching https://socialwork.charlotte.edu/directory/travis-hales-phd
#
# An error occurred while fetching https://charlotte.edu/policies/chapter-101
# An error occurred while fetching https://charlotte.edu/bookmarks?posting_id=53811
# An error occurred while fetching https://socialwork.charlotte.edu/directory/shanti-kulkarni-phd
# An error occurred while fetching https://stage-cic.charlotte.edu/referrals/referral-funding
# An error occurred while fetching https://pages.charlotte.edu/healthresearch
# An error occurred while fetching https://panorama.charlotte.edu/JNSP/index.html
# An error occurred while fetching https://pages.charlotte.edu/clas-equipment
# An error occurred while fetching https://pages.charlotte.edu/lhopper6
# An error occurred while fetching http://mrc.charlotte.edu/national-society-black-engineersAn error occurred while fetching http://mrc.charlotte.edu/society-hispanic-professional-engineers
#
# An error occurred while fetching https://guides.library.charlotte.edu/khbarchive
# An error occurred while fetching https://guides.library.charlotte.edu/LoR
# An error occurred while fetching https://panorama.charlotte.edu/Engineering/index.html
# An error occurred while fetching https://archibus.charlotte.edu/archibus/login
# An error occurred while fetching https://pages.charlotte.edu/amanda-pipkin
# An error occurred while fetching https://pages.charlotte.edu/heather-perry
# An error occurred while fetching https://pages.charlotte.edu/carolhigham
# An error occurred while fetching https://pages.charlotte.edu/willie-griffin
# An error occurred while fetching https://pages.charlotte.edu/hannah-katherine-hicks
# An error occurred while fetching https://pages.charlotte.edu/gregory-mixon
# An error occurred while fetching https://pages.charlotte.edu/christine-haynes
# An error occurred while fetching https://pages.charlotte.edu/john-david-smith
# An error occurred while fetching https://clas-pages.charlotte.edu/dennis-ogburn
# An error occurred while fetching https://clas-pages.charlotte.edu/steven-falconer
# An error occurred while fetching https://guides.library.charlotte.edu/area49/inclusiveseries
# An error occurred while fetching https://guides.library.charlotte.edu/area49resources
# An error occurred while fetching https://guides.library.charlotte.edu/area49
# An error occurred while fetching http://clas-pages.charlotte.edu/elise-berman
# An error occurred while fetching http://clas-pages.charlotte.edu/inss
# An error occurred while fetching http://clas-pages.charlotte.edu/nicole-peterson
# An error occurred while fetching http://clas-pages.charlotte.edu/gregory-starrett
# An error occurred while fetching https://pages.charlotte.edu/ritika-prasad
# An error occurred while fetching https://clas-chemistry.charlotte.edu/joanna-krueger
# An error occurred while fetching https://pages.charlotte.edu/vaughn-schmutz
# An error occurred while fetching https://pages.charlotte.edu/jyavorsk
# An error occurred while fetching https://pages.charlotte.edu/stephaniemoller
# An error occurred while fetching https://pages.charlotte.edu/kendra-jason
# An error occurred while fetching https://pages.charlotte.edu/joseph-dippong
# An error occurred while fetching https://pages.charlotte.edu/rootsofstem
# An error occurred while fetching https://pages.charlotte.edu/lisa-walker
# An error occurred while fetching https://pages.charlotte.edu/martha-cecilia-bottia
# An error occurred while fetching https://pages.charlotte.edu/elizabeth-stearns
# An error occurred while fetching https://pages.charlotte.edu/scott-fitzgerald
# An error occurred while fetching https://pages.charlotte.edu/yang-cao
# An error occurred while fetching https://clas-chemistry.charlotte.edu/vivero-research
# An error occurred while fetching https://clas-chemistry.charlotte.edu/brian-cooper
# An error occurred while fetching https://clas-chemistry.charlotte.edu/walter-research-group
# An error occurred while fetching https://clas-chemistry.charlotte.edu/jerry-troutman-research
# An error occurred while fetching https://pages.charlotte.edu/nathaniel-fried
# An error occurred while fetching http://clas-chemistry.charlotte.edu/markus-etzkorn
# An error occurred while fetching https://pages.charlotte.edu/sandra-clinton
# An error occurred while fetching https://pages.charlotte.edu/scott-hippensteel
# An error occurred while fetching https://pages.charlotte.edu/hcl
# c:\Users\Ryan\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# An error occurred while fetching https://pages.charlotte.edu/mc-eppes
# An error occurred while fetching https://pages.charlotte.edu/david-vinson
# An error occurred while fetching https://pages.charlotte.edu/youngseob-eum
# An error occurred while fetching https://hrltma.charlotte.edu:81
# An error occurred while fetching https://pages.charlotte.edu/aarif
# An error occurred while fetching https://pages.charlotte.edu/mcarney4
# An error occurred while fetching https://pages.charlotte.edu/scacace
# An error occurred while fetching https://pages.charlotte.edu/lgunn
# An error occurred while fetching https://pages.charlotte.edu/jean-claude-thill
# An error occurred while fetching https://pages.charlotte.edu/adahl3
# An error occurred while fetching https://confucius.charlotte.edu
# An error occurred while fetching https://pages.charlotte.edu/jaclyn-piatak/research
# An error occurred while fetching https://pages.charlotte.edu/julia-marie-robinson

# %%
# PreProcess the data
from collections import Counter
import re

with open(FILENAME, 'r', newline='', encoding="utf-8") as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    data = list(reader)

# Split text into chunks
chunks = [re.split('\.|-', row[2]) for row in data]

# Flatten the list of chunks and count each chunk
counter = Counter(chunk for sublist in chunks for chunk in sublist)

# Define a threshold for what you consider "too frequent"
threshold = 15

# Preprocess the data
preprocessed_data = []
for row in data:
    url = row[0]
    status = row[1]
    text = row[2]
    
    if status == 'Failed' or len(text) < 100:
        continue
    
    # Remove chunks that appear too frequently
    text = '. '.join(chunk for chunk in re.split('\.|-', text) if counter[chunk] <= threshold)
    
    preprocessed_data.append([url, status, text])
    
# Write the preprocessed data to a new CSV file
with open(PREPROCESSED_FILENAME, 'w', newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(['URL', 'Status', 'Text'])  # Write the column labels
    for row in preprocessed_data:
        writer.writerow(row)
    file.flush()
    os.fsync(file.fileno())

# %%
# %pip install txtai
# Out:
# Collecting txtai
#   Using cached txtai-6.3.0-py3-none-any.whl.metadata (24 kB)
# Collecting faiss-cpu>=1.7.1.post2 (from txtai)
#   Using cached faiss_cpu-1.7.4-cp311-cp311-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: torch>=1.12.1 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (2.1.0.dev20230615+cu121)
# Requirement already satisfied: transformers>=4.22.0 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (4.30.2)
# Requirement already satisfied: huggingface-hub>=0.9.0 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (0.15.1)
# Requirement already satisfied: numpy>=1.18.4 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (1.24.3)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (6.0)
# Requirement already satisfied: regex>=2022.8.17 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from txtai) (2023.6.3)
# Requirement already satisfied: filelock in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.9.0->txtai) (3.12.2)
# Requirement already satisfied: fsspec in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.9.0->txtai) (2023.6.0)
# Requirement already satisfied: requests in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.9.0->txtai) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.9.0->txtai) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.9.0->txtai) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ryan\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.9.0->txtai) (23.1)
# Requirement already satisfied: sympy in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.12.1->txtai) (1.12)
# Requirement already satisfied: networkx in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.12.1->txtai) (3.1)
# Requirement already satisfied: jinja2 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.12.1->txtai) (3.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.22.0->txtai) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.22.0->txtai) (0.3.1)
# Requirement already satisfied: colorama in c:\users\ryan\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.9.0->txtai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.12.1->txtai) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.9.0->txtai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.9.0->txtai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.9.0->txtai) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.9.0->txtai) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ryan\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.12.1->txtai) (1.3.0)
# Using cached txtai-6.3.0-py3-none-any.whl (205 kB)
# Using cached faiss_cpu-1.7.4-cp311-cp311-win_amd64.whl (10.8 MB)
# Installing collected packages: faiss-cpu, txtai
# Successfully installed faiss-cpu-1.7.4 txtai-6.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Txtai example

# %%
## Txtai
import txtai

# Import the preprocessed data
with open(PREPROCESSED_FILENAME, 'r', newline='', encoding="utf-8") as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    data = list(reader)
    
# Create embeddings for each web page
embeddings = txtai.Embeddings(content=True)
embeddings.index([(row[0], row[2]) for row in data])

# %%
results = embeddings.search("computer science masters program requirements", 2)
print("computer science masters program requirements")
for result in results:
    print(result['id'])

results = embeddings.search("football team", 2)
print("football team")
for result in results:
    print(result['id'])
    
embeddings.explain("computer science masters program requirements", limit=1)
# Out:
# computer science masters program requirements
# https://cci.charlotte.edu/academics/bachelor-degrees
# https://ece.charlotte.edu/graduate-program/masters-program
# football team
# https://crowdfund.charlotte.edu/project/1695
# https://crowdfund.charlotte.edu/project/38491
# [{'id': 'https://cci.charlotte.edu/academics/bachelor-degrees',
#   'text': 'Undergraduate – College of Computing and Informatics Skip to Main Content Undergraduate The College of Computing and Informatics offers a B.  and a B.  in Computer Science as well as an undergraduate certificate in Game Design.  In addition, the College offers an Honors program and an Early Entry program.  The B.  in Computer Science offers seven different concentrations.  The degree has 25 hours of core Computer Science courses, a series of courses to choose from as major electives, and 9. 15 semester hours of related work in a discipline outside computer science, possibly forming a minor in that discipline area.  The B.  in Computer Science offers four (4) concentrations and it is less structured than the B.  providing the student more flexibility in how to combine the B.  with other academic programs of study.  The B.  includes a core of 5 courses that are generally prerequisites for most upper level courses in computing.  The concentrations include: Loading… Loading… Loading… The School of Data Science (SDS) undergraduate program is designed to equip students of all backgrounds and with any level of programming and statistics experience to become innovators in the field of data science.  Data Science is at the forefront of industry in the 21st century, as more and more companies and academic disciplines rely on data. driven research, decision making, and visualizations.  As a program rooted in a four. college partnership, students who complete the major in data science will have the ability to apply theories and technologies to problems in domains across the humanities, social sciences, and sciences.  Students will take courses in machine learning, data analysis, statistics, data visualization, and most importantly the ethics surrounding the field of data science.  Possible jobs for graduates of the undergraduate program include data science engineer, data analyst, research engineer, data science developer, among others.  Data Science, B.  The Undergraduate Certificate in Game Design provides undergraduate students with the opportunity to reach a demonstrated level of competence in game design and development.  Course. work towards the certificate can be used for credit towards the Bachelor’s degree in Computer Science.  However, its primary purpose is to provide a well. defined target for students who want to advance their knowledge of modern game design and development techniques and work with a variety of professionals,from artists to writers,to being the vision for an interactive game or media product to life.  The certificate may be pursued concurrently with any of the undergraduate degree programs at UNC Charlotte.  Loading… The Early Entry Program is a special, fast. track program for highly motivated undergraduate students who desire to pursue graduate studies at an accelerated pace.  This program provides a student an opportunity to earn two degrees (Bachellors and a Master’s) in 5 years.  By taking certain graduate courses in their senior year in lieu of the corresponding undergraduate courses, a student can obtain his or her B.  or B.  degree and then, with an additional year of graduate studies, obtain a M.  degree in Information Technology.  Successful completion of this program may cut a year off the typical length in time required to obtain an M.  degree in Information Technology from UNC Charlotte.  Loading… Loading… Loading… The Honors Program in the College of Computing and Inforrmatics provides creative, imaginative, and exceptional undergraduate CCI students the opportunity to develop their potential through smaller classes and a more challenging curriculum.  CCI Honors students complete a tailored experiential learning curriculum that provides hands. on training that is not typically provided in the classroom.  This training culminates in a senior honors project that can be tailored to a variety of interests, including entrepreneurship, research, and industry.  Loading…',
#   'score': 0.5956898927688599,
#   'tokens': [('Undergraduate', 0.0007492899894714355),
#    ('–', 0.002740025520324707),
#    ('College', 0.0013383030891418457),
#    ('of', 0.0017647147178649902),
#    ('Computing', 0.0027605295181274414),
#    ('and', 0.0012778043746948242),
#    ('Informatics', 0.003673553466796875),
#    ('Skip', 0.0030804872512817383),
#    ('to', 0.00219118595123291),
#    ('Main', 0.002767324447631836),
#    ('Content', 0.0023061633110046387),
#    ('Undergraduate', 0.002493619918823242),
#    ('The', 0.0024864673614501953),
#    ('College', 0.0023696422576904297),
#    ('of', 0.002116560935974121),
#    ('Computing', 0.0028475522994995117),
#    ('and', 0.0021114349365234375),
#    ('Informatics', 0.004685521125793457),
#    ('offers', 0.002699613571166992),
#    ('a', 0.0022655129432678223),
#    ('B.', 0.004918813705444336),
#    ('and', 0.002261221408843994),
#    ('a', 0.002306818962097168),
#    ('B.', 0.0052471160888671875),
#    ('in', 0.0025856494903564453),
#    ('Computer', 0.0051152706146240234),
#    ('Science', 0.002762317657470703),
#    ('as', 0.0026440024375915527),
#    ('well', 0.002190828323364258),
#    ('as', 0.0026227235794067383),
#    ('an', 0.0024532079696655273),
#    ('undergraduate', 0.003115415573120117),
#    ('certificate', 0.00412750244140625),
#    ('in', 0.0006519556045532227),
#    ('Game', -0.002295255661010742),
#    ('Design.', 0.0025559663772583008),
#    ('In', 0.0012810826301574707),
#    ('addition,', 0.0032921433448791504),
#    ('the', 0.001897573471069336),
#    ('College', 0.000643312931060791),
#    ('offers', 0.0016820430755615234),
#    ('an', 0.0017453432083129883),
#    ('Honors', 0.0031621456146240234),
#    ('program', 0.002713441848754883),
#    ('and', 0.0009366869926452637),
#    ('an', 0.0014333724975585938),
#    ('Early', 0.00244063138961792),
#    ('Entry', 0.002287626266479492),
#    ('program.', 0.005697309970855713),
#    ('The', 0.0015677809715270996),
#    ('B.', 0.003651738166809082),
#    ('in', 0.0015091896057128906),
#    ('Computer', 0.0064122676849365234),
#    ('Science', 0.0024976730346679688),
#    ('offers', 0.0024671554565429688),
#    ('seven', 0.0031832456588745117),
#    ('different', 0.0012538433074951172),
#    ('concentrations.', 0.0036410093307495117),
#    ('The', 0.0017341375350952148),
#    ('degree', 0.0021741390228271484),
#    ('has', 0.001329660415649414),
#    ('25', 0.004533052444458008),
#    ('hours', 0.003959774971008301),
#    ('of', 0.0017164945602416992),
#    ('core', 0.004897415637969971),
#    ('Computer', 0.005102872848510742),
#    ('Science', 0.0030204057693481445),
#    ('courses,', 0.004599213600158691),
#    ('a', 0.0026860833168029785),
#    ('series', 0.0021625757217407227),
#    ('of', 0.0017172694206237793),
#    ('courses', 0.0025060176849365234),
#    ('to', 0.0023369193077087402),
#    ('choose', 0.0022758841514587402),
#    ('from', 0.002043485641479492),
#    ('as', 0.0019376873970031738),
#    ('major', 0.002302706241607666),
#    ('electives,', 0.006663978099822998),
#    ('and', 0.0016922950744628906),
#    ('9.', 0.003142118453979492),
#    ('15', 0.0033028125762939453),
#    ('semester', 0.0021611452102661133),
#    ('hours', 0.0024951696395874023),
#    ('of', 0.0015379786491394043),
#    ('related', 0.0016589164733886719),
#    ('work', 0.0011191368103027344),
#    ('in', 0.001377701759338379),
#    ('a', 0.001568913459777832),
#    ('discipline', 0.0014045238494873047),
#    ('outside', 0.0008091926574707031),
#    ('computer', 0.003175020217895508),
#    ('science,', 0.003932297229766846),
#    ('possibly', 0.002054274082183838),
#    ('forming', 0.0017757415771484375),
#    ('a', 0.001808762550354004),
#    ('minor', 0.002621173858642578),
#    ('in', 0.0017728209495544434),
#    ('that', 0.0024144649505615234),
#    ('discipline', 0.0016349554061889648),
#    ('area.', 0.004652976989746094),
#    ('The', 0.0020411014556884766),
#    ('B.', 0.003844022750854492),
#    ('in', 0.0017029047012329102),
#    ('Computer', 0.011584877967834473),
#    ('Science', 0.00324094295501709),
#    ('offers', 0.003734409809112549),
#    ('four', 0.0031806230545043945),
#    ('(4)', 0.007926225662231445),
#    ('concentrations', -0.0003578066825866699),
#    ('and', 0.0009413957595825195),
#    ('it', 0.001002192497253418),
#    ('is', 0.0013200044631958008),
#    ('less', 0.0014162659645080566),
#    ('structured', 0.00162506103515625),
#    ('than', 0.0019015669822692871),
#    ('the', 0.00182265043258667),
#    ('B.', 0.004031836986541748),
#    ('providing', 0.0023118257522583008),
#    ('the', 0.0019565224647521973),
#    ('student', 0.0011609792709350586),
#    ('more', 0.0014097094535827637),
#    ('flexibility', 0.0014051198959350586),
#    ('in', 0.0014293789863586426),
#    ('how', 0.00139695405960083),
#    ('to', 0.001675724983215332),
#    ('combine', 0.0020933151245117188),
#    ('the', 0.002170085906982422),
#    ('B.', 0.002597332000732422),
#    ('with', 0.0009171962738037109),
#    ('other', 0.0014100074768066406),
#    ('academic', 0.001313626766204834),
#    ('programs', 0.002252340316772461),
#    ('of', 0.0004922151565551758),
#    ('study.', 0.0050147175788879395),
#    ('The', 0.0025576353073120117),
#    ('B.', 0.004685640335083008),
#    ('includes', 0.002580106258392334),
#    ('a', 0.0015902519226074219),
#    ('core', 0.0022734999656677246),
#    ('of', -0.00035434961318969727),
#    ('5', 0.003743588924407959),
#    ('courses', 0.0016165375709533691),
#    ('that', -0.0015240907669067383),
#    ('are', 0.0019279718399047852),
#    ('generally', 0.0024570226669311523),
#    ('prerequisites', 0.011415243148803711),
#    ('for', 0.0016982555389404297),
#    ('most', 0.0020221471786499023),
#    ('upper', 0.0026656389236450195),
#    ('level', 0.0017911195755004883),
#    ('courses', 0.0024182796478271484),
#    ('in', 0.0015007257461547852),
#    ('computing.', 0.005506455898284912),
#    ('The', 0.0012205839157104492),
#    ('concentrations', 0.0008429288864135742),
#    ('include:', 0.008731067180633545),
#    ('Loading…', 0.003251194953918457),
#    ('Loading…', 0.003251194953918457),
#    ('Loading…', 0.003251194953918457),
#    ('The', -0.000880122184753418),
#    ('School', 0.004715979099273682),
#    ('of', -0.0006926655769348145),
#    ('Data', -0.0009611248970031738),
#    ('Science', -0.0003142356872558594),
#    ('(SDS)', 0.015180587768554688),
#    ('undergraduate', 0.0020290613174438477),
#    ('program', 0.003443121910095215),
#    ('is', 0.003925442695617676),
#    ('designed', 0.0013773441314697266),
#    ('to', 0.0008423328399658203),
#    ('equip', 0.004802823066711426),
#    ('students', 0.0014723539352416992),
#    ('of', 0.0006784796714782715),
#    ('all', 0.0008976459503173828),
#    ('backgrounds', 0.0016247034072875977),
#    ('and', 0.0004869699478149414),
#    ('with', 0.0007485151290893555),
#    ('any', 0.0006982684135437012),
#    ('level', 0.0011940598487854004),
#    ('of', 0.0007826685905456543),
#    ('programming', 0.0023688077926635742),
#    ('and', -0.0011303424835205078),
#    ('statistics', 0.0010012984275817871),
#    ('experience', 0.0009999275207519531),
#    ('to', 0.0012074112892150879),
#    ('become', 0.0009031295776367188),
#    ('innovators', 0.002816438674926758),
#    ('in', 0.0016514062881469727),
#    ('the', 0.0007630586624145508),
#    ('field', 0.001277327537536621),
#    ('of', 0.0007257461547851562),
#    ('data', -0.00011914968490600586),
#    ('science.', 0.0049588680267333984),
#    ('Data', -0.00038313865661621094),
#    ('Science', -0.0015140771865844727),
#    ('is', 0.0004203319549560547),
#    ('at', 0.0019562244415283203),
#    ('the', 0.0005730390548706055),
#    ('forefront', 0.0006486773490905762),
#    ('of', 0.0010319948196411133),
#    ('industry', 0.0008853673934936523),
#    ('in', 0.0009745359420776367),
#    ('the', 0.0007317066192626953),
#    ('21st', 0.0007782578468322754),
#    ('century,', 0.004235982894897461),
#    ('as', 0.0010793209075927734),
#    ('more', 0.0014667510986328125),
#    ('and', 0.0010287761688232422),
#    ('more', 0.0014930367469787598),
#    ('companies', 0.0011872649192810059),
#    ('and', 0.001989424228668213),
#    ('academic', 0.0016381144523620605),
#    ('disciplines', 0.0008758306503295898),
#    ('rely', 0.001872420310974121),
#    ('on', 0.0014829635620117188),
#    ('data.', 0.003991603851318359),
#    ('driven', 0.0002697110176086426),
#    ('research,', 0.004186868667602539),
#    ('decision', 0.0017652511596679688),
#    ('making,', 0.004584610462188721),
#    ('and', 0.0014175176620483398),
#    ('visualizations.', 0.0038098692893981934),
#    ('As', -0.0006234645843505859),
#    ('a', 0.000599980354309082),
#    ('program', 0.0017268061637878418),
#    ('rooted', -0.0006661415100097656),
#    ('in', 0.0008920431137084961),
#    ('a', 0.0001685023307800293),
#    ('four.', 0.0048171281814575195),
#    ('college', 0.0013480782508850098),
#    ('partnership,', 0.0019556283950805664),
#    ('students', 0.0015184283256530762),
#    ('who', 0.001156449317932129),
#    ('complete', 0.0019463300704956055),
#    ('the', -0.0010360479354858398),
#    ('major', 0.00041961669921875),
#    ('in', -0.0030933618545532227),
#    ('data', -0.0029472708702087402),
#    ('science', -0.0029711127281188965),
#    ('will', 0.0034133195877075195),
#    ('have', 0.0009015798568725586),
#    ('the', -0.00028133392333984375),
#    ('ability', -0.0014244318008422852),
#    ('to', 0.0003649592399597168),
#    ('apply', 0.00370180606842041),
#    ('theories', 0.00016880035400390625),
#    ('and', -0.0017952322959899902),
#    ('technologies', 0.0023192167282104492),
#    ('to', -0.0006773471832275391),
#    ('problems', 0.0013126730918884277),
#    ('in', 0.002234339714050293),
#    ('domains', 0.002294778823852539),
#    ('across', 0.0013772845268249512),
#    ('the', 0.0004919767379760742),
#    ('humanities,', 0.0019043684005737305),
#    ('social', 0.0010176301002502441),
#    ('sciences,', 0.0029607415199279785),
#    ('and', 0.0017911195755004883),
#    ('sciences.', 0.0056143999099731445),
#    ('Students', 0.004863858222961426),
#    ('will', 0.004386305809020996),
#    ('take', 0.0046713948249816895),
#    ('courses', 0.0049724578857421875),
#    ('in', 0.0011202096939086914),
#    ('machine', 0.008264362812042236),
#    ('learning,', 0.004229247570037842),
#    ('data', 0.0009372234344482422),
#    ('analysis,', 0.003805696964263916),
#    ('statistics,', 0.004189133644104004),
#    ('data', 0.00012755393981933594),
#    ('visualization,', 0.0031769275665283203),
#    ('and', 0.003108978271484375),
#    ('most', 0.002701103687286377),
#    ('importantly', 0.00284421443939209),
#    ('the', 0.0004731416702270508),
#    ('ethics', -0.0001251697540283203),
#    ('surrounding', 0.0011658072471618652),
#    ('the', 0.0009244084358215332),
#    ('field', 0.0009638071060180664),
#    ('of', 2.9385089874267578e-05),
#    ('data', -0.0006647706031799316),
#    ('science.', 0.005914568901062012),
#    ('Possible', 0.0008207559585571289),
#    ('jobs', -0.0007666349411010742),
#    ('for', -0.0007880926132202148),
#    ('graduates', 0.002046942710876465),
#    ('of', 0.0005991458892822266),
#    ('the', 0.0014026165008544922),
#    ('undergraduate', 0.002783060073852539),
#    ('program', 0.003791332244873047),
#    ('include', 0.005771279335021973),
#    ('data', 0.0021117329597473145),
#    ('science', 0.001119852066040039),
#    ('engineer,', 0.004507839679718018),
#    ('data', 0.0013152360916137695),
#    ('analyst,', 0.002601146697998047),
#    ('research', 0.0023377537727355957),
#    ('engineer,', 0.0033051371574401855),
#    ('data', 0.0016277432441711426),
#    ('science', 0.0011086463928222656),
#    ('developer,', 0.0016748905181884766),
#    ('among', 0.0018086433410644531),
#    ('others.', 0.003631114959716797),
#    ('Data', 0.00022453069686889648),
#    ('Science,', 0.0008147954940795898),
#    ('B.', 0.003825962543487549),
#    ('The', 0.002969503402709961),
#    ('Undergraduate', -0.00029850006103515625),
#    ('Certificate', 0.004537761211395264),
#    ('in', -0.0026473402976989746),
#    ('Game', -0.0007460713386535645),
#    ('Design', 0.0031524300575256348),
#    ('provides', 0.004287123680114746),
#    ('undergraduate', 0.0021648406982421875),
#    ('students', 0.0021157264709472656),
#    ('with', 0.002724587917327881),
#    ('the', 0.002414703369140625),
#    ('opportunity', 0.0037053823471069336),
#    ('to', 0.0025037527084350586),
#    ('reach', 0.002791166305541992),
#    ('a', 0.0022490620613098145),
#    ('demonstrated', 0.0020441412925720215),
#    ('level', 0.0027761459350585938),
#    ('of', 0.00225907564163208),
#    ('competence', 0.002092599868774414),
#    ('in', 0.0007638931274414062),
#    ('game', -0.0004439353942871094),
#    ('design', 0.0019440650939941406),
#    ('and', 0.0035636425018310547),
#    ('development.', 0.0017145872116088867),
#    ('Course.', 0.0020143985748291016),
#    ('work', 0.0018860101699829102),
#    ('towards', 0.001257479190826416),
#    ('the', 0.0005147457122802734),
#    ('certificate', 0.003462076187133789),
#    ('can', 0.0020694732666015625),
#    ('be', 0.002171158790588379),
#    ('used', 0.0033162832260131836),
#    ('for', 0.0021990537643432617),
#    ('credit', 0.002638697624206543),
#    ('towards', 0.0013333559036254883),
#    ('the', 0.0013797879219055176),
#    ('Bachelor’s', 0.002664327621459961),
#    ('degree', 0.002312779426574707),
#    ('in', 0.0009794831275939941),
#    ('Computer', 0.006060481071472168),
#    ('Science.', 0.003991186618804932),
#    ('However,', 0.0027671456336975098),
#    ('its', 0.00231325626373291),
#    ('primary', 0.0025833845138549805),
#    ('purpose', 0.0020242929458618164),
#    ('is', 0.002524435520172119),
#    ('to', 0.002534806728363037),
#    ('provide', 0.001854538917541504),
#    ('a', 0.0015087127685546875),
#    ('well.', 0.001546621322631836),
#    ('defined', 0.002097487449645996),
#    ('target', 0.0018215775489807129),
#    ('for', 0.000924229621887207),
#    ('students', 0.001685023307800293),
#    ('who', 0.0015861988067626953),
#    ('want', 0.0020722150802612305),
#    ('to', 0.0016579031944274902),
#    ('advance', 0.0020073652267456055),
#    ('their', 0.0020374059677124023),
#    ('knowledge', 0.0015507340431213379),
#    ('of', 0.0008293986320495605),
#    ('modern', 0.0008646845817565918),
#    ('game', -0.0005209445953369141),
#    ('design', 0.001160264015197754),
#    ('and', 0.0023157596588134766),
#    ('development', 0.001813650131225586),
#    ('techniques', 0.0018866658210754395),
#    ('and', 0.0028221607208251953),
#    ('work', 0.0013685226440429688),
#    ('with', 0.0013703107833862305),
#    ('a', 0.0018361806869506836),
#    ('variety', 0.002037644386291504),
#    ('of', 0.0017355680465698242),
#    ('professionals,from', 0.0017337203025817871),
#    ('artists', 0.0017063617706298828),
#    ('to', 0.0015701055526733398),
#    ('writers,to', 0.002569913864135742),
#    ('being', 0.0019574761390686035),
#    ('the', 0.0013408660888671875),
#    ('vision', 0.0010862946510314941),
#    ('for', 0.0012142658233642578),
#    ('an', 0.0021140575408935547),
#    ('interactive', 0.0010634064674377441),
#    ('game', -0.0006250739097595215),
#    ('or', 0.00277101993560791),
#    ('media', 0.0010911226272583008),
#    ('product', 0.0017039775848388672),
#    ('to', 0.002902209758758545),
#    ('life.', 0.006151676177978516),
#    ('The', 0.0014151334762573242),
#    ('certificate', 0.004718005657196045),
#    ('may', 0.0023853182792663574),
#    ('be', 0.0030777454376220703),
#    ('pursued', 0.0013872385025024414),
#    ('concurrently', 0.0037648677825927734),
#    ('with', 0.0014557838439941406),
#    ('any', 0.0016925334930419922),
#    ('of', 0.0013287067413330078),
#    ('the', 0.0012654662132263184),
#    ('undergraduate', 0.0010448694229125977),
#    ('degree', 0.001617431640625),
#    ('programs', 0.001486659049987793),
#    ('at', 9.1552734375e-05),
#    ('UNC', -0.0008689761161804199),
#    ('Charlotte.', -0.0016767382621765137),
#    ('Loading…', -0.0029126405715942383),
#    ('The', 0.0004658699035644531),
#    ('Early', 0.0018378496170043945),
#    ('Entry', 0.0017138123512268066),
#    ('Program', 0.0014815330505371094),
#    ('is', 0.0010913610458374023),
#    ('a', 0.0006909370422363281),
#    ('special,', 0.0008376240730285645),
#    ('fast.', -0.0002860426902770996),
#    ('track', 0.0019383430480957031),
#    ('program', 0.0018938779830932617),
#    ('for', -0.0008194446563720703),
#    ('highly', 0.0009993314743041992),
#    ('motivated', -0.0020589828491210938),
#    ('undergraduate', 7.200241088867188e-05),
#    ('students', 0.00010091066360473633),
#    ('who', -0.0003669261932373047),
#    ('desire', 0.0001023411750793457),
#    ('to', -1.7762184143066406e-05),
#    ('pursue', -0.0003216266632080078),
#    ('graduate', -5.960464477539063e-08),
#    ('studies', -5.960464477539063e-08),
#    ('at', -5.960464477539063e-08),
#    ('an', -5.960464477539063e-08),
#    ('accelerated', -5.960464477539063e-08),
#    ('pace.', -5.960464477539063e-08),
#    ('This', -5.960464477539063e-08),
#    ('program', -5.960464477539063e-08),
#    ('provides', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('student', -5.960464477539063e-08),
#    ('an', -5.960464477539063e-08),
#    ('opportunity', -5.960464477539063e-08),
#    ('to', -5.960464477539063e-08),
#    ('earn', -5.960464477539063e-08),
#    ('two', -5.960464477539063e-08),
#    ('degrees', -5.960464477539063e-08),
#    ('(Bachellors', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('Master’s)', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('5', -5.960464477539063e-08),
#    ('years.', 0.0),
#    ('By', 0.0),
#    ('taking', -5.960464477539063e-08),
#    ('certain', -5.960464477539063e-08),
#    ('graduate', -5.960464477539063e-08),
#    ('courses', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('their', -5.960464477539063e-08),
#    ('senior', -5.960464477539063e-08),
#    ('year', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('lieu', -5.960464477539063e-08),
#    ('of', -5.960464477539063e-08),
#    ('the', -5.960464477539063e-08),
#    ('corresponding', -5.960464477539063e-08),
#    ('undergraduate', -5.960464477539063e-08),
#    ('courses,', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('student', -5.960464477539063e-08),
#    ('can', -5.960464477539063e-08),
#    ('obtain', -5.960464477539063e-08),
#    ('his', -5.960464477539063e-08),
#    ('or', -5.960464477539063e-08),
#    ('her', -5.960464477539063e-08),
#    ('B.', -5.960464477539063e-08),
#    ('or', -5.960464477539063e-08),
#    ('B.', -5.960464477539063e-08),
#    ('degree', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('then,', -5.960464477539063e-08),
#    ('with', -5.960464477539063e-08),
#    ('an', -5.960464477539063e-08),
#    ('additional', -5.960464477539063e-08),
#    ('year', -5.960464477539063e-08),
#    ('of', -5.960464477539063e-08),
#    ('graduate', -5.960464477539063e-08),
#    ('studies,', -5.960464477539063e-08),
#    ('obtain', -5.960464477539063e-08),
#    ('a', 0.0),
#    ('M.', 0.0),
#    ('degree', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('Information', -5.960464477539063e-08),
#    ('Technology.', -5.960464477539063e-08),
#    ('Successful', -5.960464477539063e-08),
#    ('completion', -5.960464477539063e-08),
#    ('of', -5.960464477539063e-08),
#    ('this', -5.960464477539063e-08),
#    ('program', -5.960464477539063e-08),
#    ('may', -5.960464477539063e-08),
#    ('cut', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('year', -5.960464477539063e-08),
#    ('off', -5.960464477539063e-08),
#    ('the', -5.960464477539063e-08),
#    ('typical', -5.960464477539063e-08),
#    ('length', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('time', -5.960464477539063e-08),
#    ('required', -5.960464477539063e-08),
#    ('to', -5.960464477539063e-08),
#    ('obtain', -5.960464477539063e-08),
#    ('an', -5.960464477539063e-08),
#    ('M.', -5.960464477539063e-08),
#    ('degree', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('Information', -5.960464477539063e-08),
#    ('Technology', -5.960464477539063e-08),
#    ('from', -5.960464477539063e-08),
#    ('UNC', -5.960464477539063e-08),
#    ('Charlotte.', -5.960464477539063e-08),
#    ('Loading…', -5.960464477539063e-08),
#    ('Loading…', -5.960464477539063e-08),
#    ('Loading…', -5.960464477539063e-08),
#    ('The', -5.960464477539063e-08),
#    ('Honors', -5.960464477539063e-08),
#    ('Program', 0.0),
#    ('in', -5.960464477539063e-08),
#    ('the', -5.960464477539063e-08),
#    ('College', -5.960464477539063e-08),
#    ('of', -5.960464477539063e-08),
#    ('Computing', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('Inforrmatics', -5.960464477539063e-08),
#    ('provides', -5.960464477539063e-08),
#    ('creative,', -5.960464477539063e-08),
#    ('imaginative,', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('exceptional', -5.960464477539063e-08),
#    ('undergraduate', -5.960464477539063e-08),
#    ('CCI', -5.960464477539063e-08),
#    ('students', -5.960464477539063e-08),
#    ('the', -5.960464477539063e-08),
#    ('opportunity', -5.960464477539063e-08),
#    ('to', -5.960464477539063e-08),
#    ('develop', -5.960464477539063e-08),
#    ('their', -5.960464477539063e-08),
#    ('potential', -5.960464477539063e-08),
#    ('through', -5.960464477539063e-08),
#    ('smaller', -5.960464477539063e-08),
#    ('classes', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('more', -5.960464477539063e-08),
#    ('challenging', -5.960464477539063e-08),
#    ('curriculum.', -5.960464477539063e-08),
#    ('CCI', -5.960464477539063e-08),
#    ('Honors', -5.960464477539063e-08),
#    ('students', -5.960464477539063e-08),
#    ('complete', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('tailored', -5.960464477539063e-08),
#    ('experiential', -5.960464477539063e-08),
#    ('learning', 0.0),
#    ('curriculum', -5.960464477539063e-08),
#    ('that', -5.960464477539063e-08),
#    ('provides', -5.960464477539063e-08),
#    ('hands.', -5.960464477539063e-08),
#    ('on', -5.960464477539063e-08),
#    ('training', -5.960464477539063e-08),
#    ('that', -5.960464477539063e-08),
#    ('is', -5.960464477539063e-08),
#    ('not', -5.960464477539063e-08),
#    ('typically', -5.960464477539063e-08),
#    ('provided', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('the', -5.960464477539063e-08),
#    ('classroom.', -5.960464477539063e-08),
#    ('This', -5.960464477539063e-08),
#    ('training', -5.960464477539063e-08),
#    ('culminates', -5.960464477539063e-08),
#    ('in', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('senior', -5.960464477539063e-08),
#    ('honors', -5.960464477539063e-08),
#    ('project', -5.960464477539063e-08),
#    ('that', -5.960464477539063e-08),
#    ('can', -5.960464477539063e-08),
#    ('be', -5.960464477539063e-08),
#    ('tailored', -5.960464477539063e-08),
#    ('to', -5.960464477539063e-08),
#    ('a', -5.960464477539063e-08),
#    ('variety', -5.960464477539063e-08),
#    ('of', -5.960464477539063e-08),
#    ('interests,', -5.960464477539063e-08),
#    ('including', -5.960464477539063e-08),
#    ('entrepreneurship,', -5.960464477539063e-08),
#    ('research,', -5.960464477539063e-08),
#    ('and', -5.960464477539063e-08),
#    ('industry.', -5.960464477539063e-08),
#    ('Loading…', 0.0)]}]
