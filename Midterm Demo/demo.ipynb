# %%
import requests
from bs4 import BeautifulSoup

urls = ["https://www.charlotte.edu/","https://www.charlotte.edu/research","https://www.charlotte.edu/landing/campus-life"]
test_data = []

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.find('title')
    body_text = soup.find('body').get_text(strip=True, separator=' ')
    
    test_data.append({
        "url": url,
        "title": title.text,
        "body_text": body_text
    })

# %%
import pandas as pd

df = pd.DataFrame(test_data)

# %%
text_to_remove = ["Skip to main content Admissions & Financial Aid Academics Research Athletics Campus Life Diversity Alumni & Friends Faculty & Staff Prospective Students Community Current Students Parents & Family My UNC Charlotte Directory Make a Gift Library About Us Apply Now Visit Our Campus Give to UNC Charlotte Take a Virtual Tour Corporate Engagement ",
                  "Click For More Less toggle footer Campus Links Alerts Jobs Make a Gift Maps / Directions Accessibility Resources Alumni & Friends Faculty & Staff Prospective Students Community Current Students Parents and Family Stay In Touch facebook instagram flickr linkedin twitter youtube maps The University of North Carolina at Charlotte 9201 University City Blvd, Charlotte, NC 28223-0001 704-687-8622 © 2024 UNC Charlotte | All Rights Reserved Contact Us | Terms of Use | University Policies Report a Concern"]

for text in text_to_remove:
    df['body_text'] = df['body_text'].str.replace(text, '')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="cuda:0", torch_dtype=torch.bfloat16)

PROMPT = (
    "Given the url: {url}, and title: {title}, "
    "Describe the content of the webpage in 3 sentences: {body_text} ```"
)

def extract_summary(text):
    parts = text.split("```")
    if len(parts) > 1:
        return parts[1].strip().replace("<eos>", "")
    else:
        return None

def generate_summary(row):
    prompt = f"{PROMPT.format(url=row['url'], title=row['title'], body_text=row['body_text'])}"
    input_ids = tokenizer(prompt, return_tensors="pt").to("cuda:0")
    
    output = model.generate(**input_ids, max_new_tokens=50)
    return extract_summary(tokenizer.decode(output[0]))



df['summary'] = df.apply(generate_summary, axis=1)

df['summary']
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 0    This webpage is a portal to the University of ...
# 1    This webpage is a website for researchers at t...
# 2    This webpage provides a comprehensive overview...
# Name: summary, dtype: object

# %%
# print the first summary
print(df['summary'][0])
# Out:
# This webpage is a portal to the University of North Carolina at Charlotte, highlighting various news and events, academic programs, research opportunities, and student life experiences.

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
from sentence_transformers import SentenceTransformer, util
import torch

model = SentenceTransformer('msmarco-distilbert-base-v3')
embeddings = model.encode(df["summary"], convert_to_tensor=True)

def search(query, top_k):
    query_embedding = model.encode(query, convert_to_tensor=True)
    cos_scores = util.pytorch_cos_sim(query_embedding, embeddings)[0]
    cos_scores = cos_scores.cpu()

    top_results = torch.topk(cos_scores, k=top_k)

    results = []
    for idx, score in zip(top_results[1], top_results[0]):
        result_dict = {
            'url': df['url'][idx.item()],
            'score': score.item(),
            'title': df['title'][idx.item()],
            'summary': df['summary'][idx.item()],
        }
        results.append(result_dict)

    return results

# %%
print(search('research', 1))
print(search('campus life', 2))
print(search('home page', 3))
# Out:
# [{'url': 'https://www.charlotte.edu/research', 'score': 0.40909749269485474, 'title': 'Research at the University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage is a website for researchers at the University of North Carolina at Charlotte. It provides information about the research conducted by faculty and staff, as well as the research collaborations and funding opportunities available to researchers.'}]
# [{'url': 'https://www.charlotte.edu/landing/campus-life', 'score': 0.303379625082016, 'title': 'Campus life at the University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage provides a comprehensive overview of the various activities and resources available on campus at the University of North Carolina at Charlotte. It highlights the many opportunities for students to get involved and make new friends, as well as the many events and activities that are'}, {'url': 'https://www.charlotte.edu/', 'score': 0.3017105460166931, 'title': 'The University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage is a portal to the University of North Carolina at Charlotte, highlighting various news and events, academic programs, research opportunities, and student life experiences.'}]
# [{'url': 'https://www.charlotte.edu/', 'score': 0.29890769720077515, 'title': 'The University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage is a portal to the University of North Carolina at Charlotte, highlighting various news and events, academic programs, research opportunities, and student life experiences.'}, {'url': 'https://www.charlotte.edu/research', 'score': 0.19604824483394623, 'title': 'Research at the University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage is a website for researchers at the University of North Carolina at Charlotte. It provides information about the research conducted by faculty and staff, as well as the research collaborations and funding opportunities available to researchers.'}, {'url': 'https://www.charlotte.edu/landing/campus-life', 'score': 0.17077209055423737, 'title': 'Campus life at the University of North Carolina at Charlotte | UNC Charlotte', 'summary': 'This webpage provides a comprehensive overview of the various activities and resources available on campus at the University of North Carolina at Charlotte. It highlights the many opportunities for students to get involved and make new friends, as well as the many events and activities that are'}]

# %%
import nest_asyncio
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
import uvicorn

app = FastAPI()

@app.get("/search")
def search_api(query: str, top_k: int):
    if top_k > len(df):
        top_k = len(df)
    if query.strip() == "":
        return []
    return search(query, top_k)

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# Required for running server in Jupyter notebook
nest_asyncio.apply()
uvicorn.run(app, host='localhost', port=8000)
# Out:
# INFO:     Started server process [1368]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:64560 - "GET /search?query=%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64560 - "GET /search?query=%20%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64560 - "GET /search?query=%20%20%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64560 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64560 - "GET /search?query=t&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=tes&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64562 - "GET /search?query=te&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=test&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=r&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64562 - "GET /search?query=re&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=res&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=rese&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=resea&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=resear&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=researc&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=research&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=h&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=ho&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64562 - "GET /search?query=hom&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64569 - "GET /search?query=home&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20p&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20pa&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20pag&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=home%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64563 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64589 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64605 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64605 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64605 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64623 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64656 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64656 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64695 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64706 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64706 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64706 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64706 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64724 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64730 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64734 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64750 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64750 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64752 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64751 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:64882 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:64899 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:64925 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoe&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64935 - "GET /search?query=hoem&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoem&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hoe&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64935 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64937 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64934 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65037 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65058 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65210 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65229 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65229 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65234 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65235 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65236 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65267 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65286 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65299 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65319 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65324 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65324 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65333 - "GET /search?query=t&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65333 - "GET /search?query=te&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65333 - "GET /search?query=tes&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65334 - "GET /search?query=test&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65334 - "GET /search?query=test&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65334 - "GET /search?query=test&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65334 - "GET /search?query=test&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65334 - "GET /search?query=test&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65347 - "GET /search?query=test&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65347 - "GET /search?query=test&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65351 - "GET /search?query=tes&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65351 - "GET /search?query=te&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65351 - "GET /search?query=t&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65351 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65351 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65352 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65354 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65353 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:65491 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65513 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65513 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=t&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=te&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=tes&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=test&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=test%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=test%20h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65520 - "GET /search?query=test%20ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65522 - "GET /search?query=test%20hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65522 - "GET /search?query=test%20home&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:49295 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49311 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49311 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20o&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20oa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20oag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20oa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20o&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20page&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49336 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:49396 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49405 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49405 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49423 - "GET /search?query=j&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49423 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49423 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49423 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=homep&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=homepa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=homepag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=homepage&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=homepage&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=r&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49428 - "GET /search?query=re&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=rea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=re&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=res&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=rese&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=resea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=reseaa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=reseaar&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=reseaarc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=reseaar&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=reseaa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=resea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=resear&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=researc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=%20%20%20%20%3Chr%3E&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=%20%20%20%20%3C&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=d&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49435 - "GET /search?query=dfg&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=dfgl&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49435 - "GET /search?query=dfglk&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=dfglkg&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49435 - "GET /search?query=dfglkgdf&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=dfglkgd&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=dfglkgdfk&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49435 - "GET /search?query=dfglkgdfkl&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=dfglkgdfklj&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49435 - "GET /search?query=soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=socialli&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=sociall&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=socialliz&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=sociallizi&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=sociallizin&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=sociallizing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=ef&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=eff&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effe&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effec&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20o&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=effect%20of%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=effect%20of%20sol&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20solc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20sol&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20i&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20in&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20int&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20inte&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20inter&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20intera&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20interac&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20interact&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20interacti&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20interactio&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=effect%20of%20social%20interaction&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49445 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=effect%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=effect%20of%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=er&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49445 - "GET /search?query=erw&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=er&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=r&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49436 - "GET /search?query=re&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=rea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=re&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=res&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=rese&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=resea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=resear&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=researc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20o&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20i&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20in&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20ins&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20inst&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20ins&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20in&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20int&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20inte&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20inter&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49424 - "GET /search?query=research%20on%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49457 - "GET /search?query=don%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49457 - "GET /search?query=daon%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49457 - "GET /search?query=daton%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49457 - "GET /search?query=dataon%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49457 - "GET /search?query=data%20on%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20o%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20social&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20s&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20sc&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20sci&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20scie&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20scien&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20scienc&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20science&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49473 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=data%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=c&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=co&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=com&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=comp&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=compy&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49473 - "GET /search?query=compyu&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=compy&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=comp&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=compu&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=comput&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=compute&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=computer&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=o&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=on&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=onl&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=onli&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49473 - "GET /search?query=onlin&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=online&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=g&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=gr&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=gra&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=grad&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=gradu&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=gradua&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=graduat&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=graduati&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=graduatio&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49467 - "GET /search?query=graduation&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=f&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49487 - "GET /search?query=fir&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49486 - "GET /search?query=fi&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49488 - "GET /search?query=firn&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=fir&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49487 - "GET /search?query=fi&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49486 - "GET /search?query=f&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=fr&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49487 - "GET /search?query=fri&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49486 - "GET /search?query=frie&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=frien&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49487 - "GET /search?query=friend&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49486 - "GET /search?query=friends&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49484 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:49525 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:49542 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     ::1:49572 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49592 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=m&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50552 - "GET /search?query=ma&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=mai&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50558 - "GET /search?query=mai&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=main%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50552 - "GET /search?query=main%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50557 - "GET /search?query=main&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50556 - "GET /search?query=main%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=ma&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=m&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=r&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=re&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=res&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=rese&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=resea&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=resear&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=researc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=research&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50563 - "GET /search?query=sol&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=soli&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=sol&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50551 - "GET /search?query=soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20ev&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20eve&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20even&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20event&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20events&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=ev&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=eve&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=even&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=event&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=events&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=d&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50567 - "GET /search?query=da&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=dat&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20o&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20sc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20sco&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20sc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20e&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20ev&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20eve&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20even&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20event&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20events&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20sociali&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socializ&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50577 - "GET /search?query=data%20on%20socializa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socializat&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socializati&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socializatio&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50564 - "GET /search?query=data%20on%20socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50599 - "GET /search?query=socializationdata%20on%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50598 - "GET /search?query=socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50598 - "GET /search?query=data%20on%20socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53010 - "GET /search?query=data%20on%20socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53023 - "GET /search?query=socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53023 - "GET /search?query=data%20on%20socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53054 - "GET /search?query=data%20on%20socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53054 - "GET /search?query=data%20on%20socialization&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53054 - "GET /search?query=data%20on%20socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53054 - "GET /search?query=data%20on%20socialization&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53074 - "GET /search?query=data%20on%20socialization&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=h&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=ho&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=hom&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20p&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20pa&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20pag&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53079 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53097 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53097 - "GET /search?query=home%20page&top_k=3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53097 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53097 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59795 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20page&top_k=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=sociali&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socializ&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60445 - "GET /search?query=socializi&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socializin&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socializing%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60433 - "GET /search?query=socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=dsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=dasocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=datsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=datAsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=datsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=datasocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=data%20socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=data%20osocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=data%20onsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60449 - "GET /search?query=data%20on%20socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=h&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=ho&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=hom&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20a&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20p&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20pa&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20pag&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20page&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=home%20&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=s&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=so&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=soc&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60682 - "GET /search?query=socia&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=soci&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=socialz&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=socialzi&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=socialzin&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=socialzi&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=socialz&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=social&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=sociali&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=socializ&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=socializi&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60672 - "GET /search?query=socializin&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60681 - "GET /search?query=socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=dsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=dasocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=datsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=datasocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=data%20socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=data%20osocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=data%20onsocializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=data%20on%20socializing&top_k=1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60691 - "GET /search?query=data%20on%20socializing&top_k=2 HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1368]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 26
#      24 # Required for running server in Jupyter notebook
#      25 nest_asyncio.apply()
# ---> 26 uvicorn.run(app, host='localhost', port=8000)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\uvicorn\main.py:575, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     573     Multiprocess(config, target=server.run, sockets=[sock]).run()
#     574 else:
# --> 575     server.run()
#     576 if config.uds and os.path.exists(config.uds):
#     577     os.remove(config.uds)  # pragma: py-win32
#
# File ~\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py:65, in Server.run(self, sockets)
#      63 def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64     self.config.setup_event_loop()
# ---> 65     return asyncio.run(self.serve(sockets=sockets))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File c:\Python312\Lib\asyncio\events.py:88, in Handle._run(self)
#      86 def _run(self):
#      87     try:
# ---> 88         self._context.run(self._callback, *self._args)
#      89     except (SystemExit, KeyboardInterrupt):
#      90         raise
#
# File c:\Python312\Lib\asyncio\tasks.py:396, in Task.__wakeup(self, future)
#     388     self.__step(exc)
#     389 else:
#     390     # Don't pass the value of `future.result()` explicitly,
#     391     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     394     # instead of `__next__()`, which is slower for futures
#     395     # that return non-generator iterators from their `__iter__`.
# --> 396     self.__step()
#     397 self = None
#
# File c:\Python312\Lib\asyncio\tasks.py:303, in Task.__step(self, exc)
#     301 _enter_task(self._loop, self)
#     302 try:
# --> 303     self.__step_run_and_handle_result(exc)
#     304 finally:
#     305     _leave_task(self._loop, self)
#
# File c:\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py:68, in Server.serve(self, sockets)
#      67 async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68     with self.capture_signals():
#      69         await self._serve(sockets)
#
# File c:\Python312\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py:328, in Server.capture_signals(self)
#     324 # If we did gracefully shut down due to a signal, try to
#     325 # trigger the expected behaviour now; multiple signals would be
#     326 # done LIFO, see https://stackoverflow.com/questions/48434964
#     327 for captured_signal in reversed(self._captured_signals):
# --> 328     signal.raise_signal(captured_signal)
#
# KeyboardInterrupt:

# %%
# Call the search api

import requests

response = requests.get("http://localhost:8000/search?query=research&top_k=1")
print(response.json())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<Server.serve() done, defined at C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py:67> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ryan\AppData\Local\Temp\ipykernel_1368\3586425972.py", line 13, in <module>
#     uvicorn.run(app, host='localhost', port=8000)
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\main.py", line 575, in run
#     server.run()
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 65, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 133, in _run_once
#     handle._run()
#   File "c:\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Python312\Lib\asyncio\tasks.py", line 396, in __wakeup
#     self.__step()
#   File "c:\Python312\Lib\asyncio\tasks.py", line 303, in __step
#     self.__step_run_and_handle_result(exc)
#   File "c:\Python312\Lib\asyncio\tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 68, in serve
#     with self.capture_signals():
#   File "c:\Python312\Lib\contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 328, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<Server.serve() done, defined at C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py:67> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ryan\AppData\Local\Temp\ipykernel_1368\3586425972.py", line 13, in <module>
#     uvicorn.run(app, host='localhost', port=8000)
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\main.py", line 575, in run
#     server.run()
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 65, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\nest_asyncio.py", line 133, in _run_once
#     handle._run()
#   File "c:\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Python312\Lib\asyncio\tasks.py", line 396, in __wakeup
#     self.__step()
#   File "c:\Python312\Lib\asyncio\tasks.py", line 303, in __step
#     self.__step_run_and_handle_result(exc)
#   File "c:\Python312\Lib\asyncio\tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 68, in serve
#     with self.capture_signals():
#   File "c:\Python312\Lib\contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "C:\Users\Ryan\AppData\Roaming\Python\Python312\site-packages\uvicorn\server.py", line 328, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 5
#       1 # Call the search api
#       3 import requests
# ----> 5 response = requests.get("http://localhost:8000/search?query=research&top_k=1")
#       6 print(response.json())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Python312\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Python312\Lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File c:\Python312\Lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     398 for header, value in headers.items():
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#     403 if chunks is not None:
#
# File c:\Python312\Lib\http\client.py:1326, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1324 else:
#    1325     raise CannotSendHeader()
# -> 1326 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Python312\Lib\http\client.py:1085, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1083 msg = b"\r\n".join(self._buffer)
#    1084 del self._buffer[:]
# -> 1085 self.send(msg)
#    1087 if message_body is not None:
#    1088
#    1089     # create a consistent interface to message_body
#    1090     if hasattr(message_body, 'read'):
#    1091         # Let file-like take precedence over byte-like.  This
#    1092         # is needed to allow the current position of mmap'ed
#    1093         # files to be taken into account.
#
# File c:\Python312\Lib\http\client.py:1029, in HTTPConnection.send(self, data)
#    1027 if self.sock is None:
#    1028     if self.auto_open:
# -> 1029         self.connect()
#    1030     else:
#    1031         raise NotConnected()
#
# File c:\Python312\Lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#     241         self._has_connected_to_proxy = True
#
# File c:\Python312\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Python312\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File c:\Python312\Lib\socket.py:500, in socket.close(self)
#     496 def _real_close(self, _ss=_socket.socket):
#     497     # This function should not reference any globals. See issue #808164.
#     498     _ss.close(self)
# --> 500 def close(self):
#     501     # This function should not reference any globals. See issue #808164.
#     502     self._closed = True
#     503     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
# Small frontend to interact with the search API

from ipywidgets import interact, widgets
import requests

def search(query, top_k):
    response = requests.get(f"http://localhost:8000/search?query={query}&top_k={top_k}")
    return response.json()

interact(search, query="research", top_k=widgets.IntSlider(min=1, max=5, step=1, value=1))

interact(search, query="campus life", top_k=widgets.IntSlider(min=1, max=5, step=1, value=1))

interact(search, query="home page", top_k=widgets.IntSlider(min=1, max=5, step=1, value=1))
